# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
import requests
from datetime import datetime
import time

# %%
# create a set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f1ad8d4380c5b3b11b5ff7a2f39da92b

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | punta arenas
# Processing Record 2 of Set 16 | vestmannaeyjar
# Processing Record 3 of Set 16 | mataura
# Processing Record 4 of Set 16 | antalaha
# Processing Record 5 of Set 16 | andenes
# Processing Record 6 of Set 16 | airai
# Processing Record 7 of Set 16 | barrow
# Processing Record 8 of Set 16 | encruzilhada
# Processing Record 9 of Set 16 | hithadhoo
# Processing Record 10 of Set 16 | kapaa
# Processing Record 11 of Set 16 | rikitea
# Processing Record 12 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 16 | vaini
# Processing Record 14 of Set 16 | vao
# Processing Record 15 of Set 16 | port elizabeth
# Processing Record 16 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 16 | matay
# Processing Record 18 of Set 16 | halifax
# Processing Record 19 of Set 16 | namatanai
# Processing Record 20 of Set 16 | moose factory
# Processing Record 21 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 16 | busselton
# Processing Record 24 of Set 16 | san patricio
# Processing Record 25 of Set 16 | east london
# Processing Record 26 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 16 | avarua
# Processing Record 28 of Set 16 | ushuaia
# Processing Record 29 of Set 16 | rudbar
# Processing Record 30 of Set 16 | narrabri
# Processing Record 31 of Set 16 | kununurra
# Processing Record 32 of Set 16 | mkushi
# Processing Record 33 of Set 16 | thessalon
# Processing Record 34 of Set 16 | suraabad
# Processing Record 35 of Set 16 | la macarena
# Processing Record 36 of Set 16 | rio gallegos
# Processing Record 37 of Set 16 | luanda
# Processing Record 38 of Set 16 | garmsar
# Processing Record 39 of Set 16 | guerrero negro
# Processing Record 40 of Set 16 | tiksi
# Processing Record 41 of Set 16 | jamestown
# Processing Record 42 of Set 16 | amol
# Processing Record 43 of Set 16 | santa isabel do rio negro
# Processing Record 44 of Set 16 | bluff
# Processing Record 45 of Set 16 | nikolskoye
# Processing Record 46 of Set 16 | fasa
# Processing Record 47 of Set 16 | pipri
# Processing Record 48 of Set 16 | butaritari
# Processing Record 49 of Set 16 | bethel
# Processing Record 50 of Set 16 | ribeira grande
# Processing Record 1 of Set 17 | leningradskiy
# Processing Record 2 of Set 17 | pevek
# Processing Record 3 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 17 | ossora
# Processing Record 5 of Set 17 | albany
# Processing Record 6 of Set 17 | asind
# Processing Record 7 of Set 17 | tokuyama
# Processing Record 8 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 17 | tiznit
# Processing Record 11 of Set 17 | hilo
# Processing Record 12 of Set 17 | ugoofaaru
# Processing Record 13 of Set 17 | ozimek
# Processing Record 14 of Set 17 | tautira
# Processing Record 15 of Set 17 | nishihara
# Processing Record 16 of Set 17 | gerash
# Processing Record 17 of Set 17 | lashio
# Processing Record 18 of Set 17 | suez
# Processing Record 19 of Set 17 | phan thiet
# Processing Record 20 of Set 17 | tuy hoa
# Processing Record 21 of Set 17 | nanortalik
# Processing Record 22 of Set 17 | pundaguitan
# Processing Record 23 of Set 17 | atuona
# Processing Record 24 of Set 17 | bubaque
# Processing Record 25 of Set 17 | ola
# Processing Record 26 of Set 17 | ancud
# Processing Record 27 of Set 17 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 17 | mount gambier
# Processing Record 29 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 17 | cape town
# Processing Record 31 of Set 17 | mahebourg
# Processing Record 32 of Set 17 | port alfred
# Processing Record 33 of Set 17 | kimbe
# Processing Record 34 of Set 17 | bengkulu
# Processing Record 35 of Set 17 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 17 | sitka
# Processing Record 37 of Set 17 | stromness
# Processing Record 38 of Set 17 | ilulissat
# Processing Record 39 of Set 17 | karratha
# Processing Record 40 of Set 17 | casa nova
# Processing Record 41 of Set 17 | mokhotlong
# Processing Record 42 of Set 17 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 17 | bahia honda
# Processing Record 44 of Set 17 | new norfolk
# Processing Record 45 of Set 17 | tasiilaq
# Processing Record 46 of Set 17 | chuy
# Processing Record 47 of Set 17 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 17 | berlevag
# Processing Record 49 of Set 17 | eureka
# Processing Record 50 of Set 17 | muborak
# Processing Record 1 of Set 18 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 18 | severo-kurilsk
# Processing Record 3 of Set 18 | souillac
# Processing Record 4 of Set 18 | puerto ayora
# Processing Record 5 of Set 18 | saldanha
# Processing Record 6 of Set 18 | olafsvik
# Processing Record 7 of Set 18 | saint-pierre
# Processing Record 8 of Set 18 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 18 | clyde river
# Processing Record 10 of Set 18 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 18 | codrington
# Processing Record 12 of Set 18 | khatanga
# Processing Record 13 of Set 18 | nizhniy kuranakh
# Processing Record 14 of Set 18 | digha
# Processing Record 15 of Set 18 | mount pleasant
# Processing Record 16 of Set 18 | saint-jacques
# Processing Record 17 of Set 18 | salalah
# Processing Record 18 of Set 18 | te anau
# Processing Record 19 of Set 18 | sofiysk
# City not found. Skipping...
# Processing Record 20 of Set 18 | troitsko-pechorsk
# Processing Record 21 of Set 18 | georgetown
# Processing Record 22 of Set 18 | wanning
# Processing Record 23 of Set 18 | mar del plata
# Processing Record 24 of Set 18 | leh
# Processing Record 25 of Set 18 | nalut
# Processing Record 26 of Set 18 | mingguang
# Processing Record 27 of Set 18 | saint-philippe
# Processing Record 28 of Set 18 | chapais
# Processing Record 29 of Set 18 | yunjinghong
# City not found. Skipping...
# Processing Record 30 of Set 18 | lorengau
# Processing Record 31 of Set 18 | kattivakkam
# Processing Record 32 of Set 18 | baixa grande
# Processing Record 33 of Set 18 | labuhan
# Processing Record 34 of Set 18 | batamshinskiy
# Processing Record 35 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 18 | tiarei
# Processing Record 37 of Set 18 | carnarvon
# Processing Record 38 of Set 18 | hermanus
# Processing Record 39 of Set 18 | inirida
# Processing Record 40 of Set 18 | iquitos
# Processing Record 41 of Set 18 | port hedland
# Processing Record 42 of Set 18 | dikson
# Processing Record 43 of Set 18 | saint-augustin
# Processing Record 44 of Set 18 | presidencia roque saenz pena
# Processing Record 45 of Set 18 | arraial do cabo
# Processing Record 46 of Set 18 | camara de lobos
# Processing Record 47 of Set 18 | saskylakh
# Processing Record 48 of Set 18 | ponta delgada
# Processing Record 49 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 18 | kingman
# Processing Record 1 of Set 19 | abalak
# Processing Record 2 of Set 19 | imabari
# City not found. Skipping...
# Processing Record 3 of Set 19 | hobyo
# Processing Record 4 of Set 19 | praxedis guerrero
# Processing Record 5 of Set 19 | samana
# Processing Record 6 of Set 19 | maues
# Processing Record 7 of Set 19 | yellowknife
# Processing Record 8 of Set 19 | qaanaaq
# Processing Record 9 of Set 19 | geraldton
# Processing Record 10 of Set 19 | axim
# Processing Record 11 of Set 19 | baykit
# Processing Record 12 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 19 | bayamo
# Processing Record 14 of Set 19 | korla
# Processing Record 15 of Set 19 | roma
# Processing Record 16 of Set 19 | akyab
# Processing Record 17 of Set 19 | katsuura
# Processing Record 18 of Set 19 | ust-maya
# Processing Record 19 of Set 19 | san cristobal
# Processing Record 20 of Set 19 | kilindoni
# Processing Record 21 of Set 19 | ponta do sol
# Processing Record 22 of Set 19 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 19 | fiumicino
# Processing Record 24 of Set 19 | khandyga
# Processing Record 25 of Set 19 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 19 | lupiro
# Processing Record 27 of Set 19 | hobart
# Processing Record 28 of Set 19 | klaksvik
# Processing Record 29 of Set 19 | adrar
# Processing Record 30 of Set 19 | puri
# Processing Record 31 of Set 19 | san ramon
# Processing Record 32 of Set 19 | hofn
# Processing Record 33 of Set 19 | progreso
# Processing Record 34 of Set 19 | high rock
# Processing Record 35 of Set 19 | coquimbo
# Processing Record 36 of Set 19 | knysna
# Processing Record 37 of Set 19 | luderitz
# Processing Record 38 of Set 19 | nome
# Processing Record 39 of Set 19 | flinders
# Processing Record 40 of Set 19 | puerto baquerizo moreno
# Processing Record 41 of Set 19 | tieling
# Processing Record 42 of Set 19 | nemuro
# Processing Record 43 of Set 19 | cabo san lucas
# Processing Record 44 of Set 19 | bredasdorp
# Processing Record 45 of Set 19 | jak
# Processing Record 46 of Set 19 | carira
# Processing Record 47 of Set 19 | honda
# Processing Record 48 of Set 19 | faanui
# Processing Record 49 of Set 19 | maidens
# Processing Record 50 of Set 19 | tezu
# Processing Record 1 of Set 20 | takoradi
# Processing Record 2 of Set 20 | soure
# Processing Record 3 of Set 20 | tuktoyaktuk
# Processing Record 4 of Set 20 | hamilton
# Processing Record 5 of Set 20 | mukhen
# Processing Record 6 of Set 20 | qaqortoq
# Processing Record 7 of Set 20 | sabha
# Processing Record 8 of Set 20 | cap-haitien
# Processing Record 9 of Set 20 | amazar
# Processing Record 10 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 20 | nsukka
# Processing Record 12 of Set 20 | pitimbu
# Processing Record 13 of Set 20 | kokopo
# Processing Record 14 of Set 20 | viksoyri
# City not found. Skipping...
# Processing Record 15 of Set 20 | thompson
# Processing Record 16 of Set 20 | bathsheba
# Processing Record 17 of Set 20 | kaitangata
# Processing Record 18 of Set 20 | qui nhon
# Processing Record 19 of Set 20 | chokurdakh
# Processing Record 20 of Set 20 | jaru
# Processing Record 21 of Set 20 | verkhnyachka
# Processing Record 22 of Set 20 | pangnirtung
# Processing Record 23 of Set 20 | ostrovnoy
# Processing Record 24 of Set 20 | lebu
# Processing Record 25 of Set 20 | mamallapuram
# Processing Record 26 of Set 20 | minna
# Processing Record 27 of Set 20 | laredo
# Processing Record 28 of Set 20 | acapulco
# Processing Record 29 of Set 20 | muyezerskiy
# Processing Record 30 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 20 | daru
# Processing Record 32 of Set 20 | lavrentiya
# Processing Record 33 of Set 20 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 20 | sao jose da coroa grande
# Processing Record 35 of Set 20 | rapid valley
# Processing Record 36 of Set 20 | talnakh
# Processing Record 37 of Set 20 | longyearbyen
# Processing Record 38 of Set 20 | svirstroy
# Processing Record 39 of Set 20 | bethanien
# Processing Record 40 of Set 20 | cayenne
# Processing Record 41 of Set 20 | hervey bay
# Processing Record 42 of Set 20 | kahului
# Processing Record 43 of Set 20 | beringovskiy
# Processing Record 44 of Set 20 | yulara
# Processing Record 45 of Set 20 | nyurba
# Processing Record 46 of Set 20 | road town
# Processing Record 47 of Set 20 | lazarev
# Processing Record 48 of Set 20 | bontang
# Processing Record 49 of Set 20 | leshukonskoye
# Processing Record 50 of Set 20 | kendari
# Processing Record 1 of Set 21 | singaraja
# Processing Record 2 of Set 21 | shu
# Processing Record 3 of Set 21 | ixtapa
# Processing Record 4 of Set 21 | kerema
# Processing Record 5 of Set 21 | shingu
# Processing Record 6 of Set 21 | taoudenni
# Processing Record 7 of Set 21 | san juan del sur
# Processing Record 8 of Set 21 | hualmay
# Processing Record 9 of Set 21 | lompoc
# Processing Record 10 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 21 | urubamba
# Processing Record 12 of Set 21 | mugur-aksy
# Processing Record 13 of Set 21 | palembang
# Processing Record 14 of Set 21 | valparaiso
# Processing Record 15 of Set 21 | raga
# Processing Record 16 of Set 21 | kovdor
# Processing Record 17 of Set 21 | jiangyou
# Processing Record 18 of Set 21 | zaysan
# Processing Record 19 of Set 21 | imeni poliny osipenko
# Processing Record 20 of Set 21 | najran
# Processing Record 21 of Set 21 | aykhal
# Processing Record 22 of Set 21 | castro
# Processing Record 23 of Set 21 | cairns
# Processing Record 24 of Set 21 | margate
# Processing Record 25 of Set 21 | ryotsu
# Processing Record 26 of Set 21 | xique-xique
# Processing Record 27 of Set 21 | ratnapura
# Processing Record 28 of Set 21 | shimoda
# Processing Record 29 of Set 21 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 21 | pingliang
# Processing Record 31 of Set 21 | vostok
# Processing Record 32 of Set 21 | issia
# Processing Record 33 of Set 21 | aybak
# City not found. Skipping...
# Processing Record 34 of Set 21 | fomboni
# Processing Record 35 of Set 21 | tuatapere
# Processing Record 36 of Set 21 | praia da vitoria
# Processing Record 37 of Set 21 | santa fe
# Processing Record 38 of Set 21 | waipawa
# Processing Record 39 of Set 21 | lubartow
# Processing Record 40 of Set 21 | maneadero
# Processing Record 41 of Set 21 | sorong
# Processing Record 42 of Set 21 | omboue
# Processing Record 43 of Set 21 | fairbanks
# Processing Record 44 of Set 21 | safford
# Processing Record 45 of Set 21 | yenagoa
# Processing Record 46 of Set 21 | kavieng
# Processing Record 47 of Set 21 | dongsheng
# Processing Record 48 of Set 21 | trebisov
# Processing Record 49 of Set 21 | muros
# Processing Record 50 of Set 21 | hajdudorog
# Processing Record 1 of Set 22 | beira
# Processing Record 2 of Set 22 | dakar
# Processing Record 3 of Set 22 | puerto escondido
# Processing Record 4 of Set 22 | cherskiy
# Processing Record 5 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 22 | itarema
# Processing Record 9 of Set 22 | kodiak
# Processing Record 10 of Set 22 | seka
# Processing Record 11 of Set 22 | nisia floresta
# Processing Record 12 of Set 22 | belmonte
# Processing Record 13 of Set 22 | nsanje
# Processing Record 14 of Set 22 | tangwani
# Processing Record 15 of Set 22 | mafinga
# Processing Record 16 of Set 22 | bayir
# Processing Record 17 of Set 22 | panzhihua
# Processing Record 18 of Set 22 | victoria
# Processing Record 19 of Set 22 | portales
# Processing Record 20 of Set 22 | port lincoln
# Processing Record 21 of Set 22 | jumla
# Processing Record 22 of Set 22 | jaipur hat
# City not found. Skipping...
# Processing Record 23 of Set 22 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 22 | lucapa
# Processing Record 25 of Set 22 | mopipi
# Processing Record 26 of Set 22 | ahipara
# Processing Record 27 of Set 22 | santomera
# Processing Record 28 of Set 22 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 22 | aswan
# Processing Record 30 of Set 22 | tazovskiy
# Processing Record 31 of Set 22 | staryy nadym
# Processing Record 32 of Set 22 | plettenberg bay
# Processing Record 33 of Set 22 | gemona
# Processing Record 34 of Set 22 | batticaloa
# Processing Record 35 of Set 22 | grootfontein
# Processing Record 36 of Set 22 | paragominas
# Processing Record 37 of Set 22 | berea
# Processing Record 38 of Set 22 | limbazi
# Processing Record 39 of Set 22 | auki
# Processing Record 40 of Set 22 | cidreira
# Processing Record 41 of Set 22 | kidal
# Processing Record 42 of Set 22 | starogard gdanski
# Processing Record 43 of Set 22 | cam ranh
# Processing Record 44 of Set 22 | boende
# Processing Record 45 of Set 22 | coxim
# Processing Record 46 of Set 22 | tarakan
# Processing Record 47 of Set 22 | yar-sale
# Processing Record 48 of Set 22 | pindiga
# Processing Record 49 of Set 22 | dilla
# Processing Record 50 of Set 22 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 23 | marapanim
# Processing Record 2 of Set 23 | vila velha
# Processing Record 3 of Set 23 | vardo
# Processing Record 4 of Set 23 | bambous virieux
# Processing Record 5 of Set 23 | marsabit
# Processing Record 6 of Set 23 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 23 | karlshamn
# Processing Record 8 of Set 23 | bowen
# Processing Record 9 of Set 23 | lagoa
# Processing Record 10 of Set 23 | roanoke rapids
# Processing Record 11 of Set 23 | dingle
# Processing Record 12 of Set 23 | metro
# Processing Record 13 of Set 23 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 23 | paamiut
# Processing Record 15 of Set 23 | san jeronimo
# Processing Record 16 of Set 23 | alofi
# Processing Record 17 of Set 23 | shiyan
# Processing Record 18 of Set 23 | hirara
# Processing Record 19 of Set 23 | baicheng
# Processing Record 20 of Set 23 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 23 | santa maria
# Processing Record 22 of Set 23 | ucluelet
# Processing Record 23 of Set 23 | isangel
# Processing Record 24 of Set 23 | kayes
# Processing Record 25 of Set 23 | pijijiapan
# Processing Record 26 of Set 23 | kloulklubed
# Processing Record 27 of Set 23 | banyo
# Processing Record 28 of Set 23 | mayor pablo lagerenza
# Processing Record 29 of Set 23 | camacha
# Processing Record 30 of Set 23 | catamarca
# Processing Record 31 of Set 23 | richards bay
# Processing Record 32 of Set 23 | fortuna
# Processing Record 33 of Set 23 | cururupu
# Processing Record 34 of Set 23 | matagami
# Processing Record 35 of Set 23 | beaverlodge
# Processing Record 36 of Set 23 | samarai
# Processing Record 37 of Set 23 | del rio
# Processing Record 38 of Set 23 | westpunt
# City not found. Skipping...
# Processing Record 39 of Set 23 | vorokhta
# Processing Record 40 of Set 23 | mundo nuevo
# Processing Record 41 of Set 23 | roald
# Processing Record 42 of Set 23 | port-gentil
# Processing Record 43 of Set 23 | ust-tsilma
# Processing Record 44 of Set 23 | zhezkazgan
# Processing Record 45 of Set 23 | san pedro
# Processing Record 46 of Set 23 | zhigansk
# Processing Record 47 of Set 23 | kadoma
# Processing Record 48 of Set 23 | naze
# Processing Record 49 of Set 23 | broome
# Processing Record 50 of Set 23 | provideniya
# Processing Record 1 of Set 24 | timmins
# Processing Record 2 of Set 24 | faya
# Processing Record 3 of Set 24 | bulgan
# Processing Record 4 of Set 24 | bilibino
# Processing Record 5 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 24 | portland
# Processing Record 7 of Set 24 | klyuchi
# Processing Record 8 of Set 24 | touros
# Processing Record 9 of Set 24 | kadambur
# Processing Record 10 of Set 24 | porto novo
# Processing Record 11 of Set 24 | neiafu
# Processing Record 12 of Set 24 | colonial park
# Processing Record 13 of Set 24 | barcelos
# Processing Record 14 of Set 24 | svetlaya
# Processing Record 15 of Set 24 | itoman
# Processing Record 16 of Set 24 | anito
# Processing Record 17 of Set 24 | upernavik
# Processing Record 18 of Set 24 | havoysund
# Processing Record 19 of Set 24 | sur
# Processing Record 20 of Set 24 | calabozo
# Processing Record 21 of Set 24 | haines junction
# Processing Record 22 of Set 24 | constitucion
# Processing Record 23 of Set 24 | acari
# Processing Record 24 of Set 24 | atikokan
# Processing Record 25 of Set 24 | madimba
# Processing Record 26 of Set 24 | jijiga
# Processing Record 27 of Set 24 | sisimiut
# Processing Record 28 of Set 24 | nouadhibou
# Processing Record 29 of Set 24 | churapcha
# Processing Record 30 of Set 24 | neijiang
# Processing Record 31 of Set 24 | moron
# Processing Record 32 of Set 24 | hasaki
# Processing Record 33 of Set 24 | bridlington
# Processing Record 34 of Set 24 | broken hill
# Processing Record 35 of Set 24 | lianzhou
# Processing Record 36 of Set 24 | kumluca
# Processing Record 37 of Set 24 | santa rosa de aguan
# Processing Record 38 of Set 24 | xunchang
# Processing Record 39 of Set 24 | alindao
# Processing Record 40 of Set 24 | mayumba
# Processing Record 41 of Set 24 | pilar
# Processing Record 42 of Set 24 | aitape
# Processing Record 43 of Set 24 | icatu
# Processing Record 44 of Set 24 | sosva
# Processing Record 45 of Set 24 | college
# Processing Record 46 of Set 24 | skibbereen
# Processing Record 47 of Set 24 | padang
# Processing Record 48 of Set 24 | davila
# Processing Record 49 of Set 24 | zola predosa
# Processing Record 50 of Set 24 | xining
# Processing Record 1 of Set 25 | quirinopolis
# Processing Record 2 of Set 25 | blyth
# Processing Record 3 of Set 25 | caravelas
# Processing Record 4 of Set 25 | astana
# Processing Record 5 of Set 25 | baglung
# Processing Record 6 of Set 25 | pemangkat
# Processing Record 7 of Set 25 | myitkyina
# Processing Record 8 of Set 25 | tallahassee
# Processing Record 9 of Set 25 | hornepayne
# Processing Record 10 of Set 25 | saint-francois
# Processing Record 11 of Set 25 | ormara
# Processing Record 12 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 25 | malanje
# Processing Record 14 of Set 25 | norilsk
# Processing Record 15 of Set 25 | ercis
# Processing Record 16 of Set 25 | hakvik
# City not found. Skipping...
# Processing Record 17 of Set 25 | the valley
# Processing Record 18 of Set 25 | erenhot
# Processing Record 19 of Set 25 | mumbwa
# Processing Record 20 of Set 25 | vanimo
# Processing Record 21 of Set 25 | necochea
# Processing Record 22 of Set 25 | solnechnyy
# Processing Record 23 of Set 25 | sao joao da barra
# Processing Record 24 of Set 25 | esmeralda
# Processing Record 25 of Set 25 | torbay
# Processing Record 26 of Set 25 | mount isa
# Processing Record 27 of Set 25 | grand gaube
# Processing Record 28 of Set 25 | fort nelson
# Processing Record 29 of Set 25 | caibarien
# Processing Record 30 of Set 25 | xiamen
# Processing Record 31 of Set 25 | sao filipe
# Processing Record 32 of Set 25 | saint george
# Processing Record 33 of Set 25 | robertsport
# Processing Record 34 of Set 25 | invermere
# Processing Record 35 of Set 25 | ayr
# Processing Record 36 of Set 25 | hindaun
# Processing Record 37 of Set 25 | kuah
# Processing Record 38 of Set 25 | champerico
# Processing Record 39 of Set 25 | nivala
# Processing Record 40 of Set 25 | narsaq
# Processing Record 41 of Set 25 | barinas
# Processing Record 42 of Set 25 | ferme-neuve
# Processing Record 43 of Set 25 | zachagansk
# City not found. Skipping...
# Processing Record 44 of Set 25 | zeya
# Processing Record 45 of Set 25 | viloco
# Processing Record 46 of Set 25 | east wenatchee bench
# Processing Record 47 of Set 25 | tahta
# Processing Record 48 of Set 25 | buchanan
# Processing Record 49 of Set 25 | preobrazheniye
# Processing Record 50 of Set 25 | ewa beach
# Processing Record 1 of Set 26 | pascagoula
# Processing Record 2 of Set 26 | sabang
# Processing Record 3 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 26 | biak
# Processing Record 5 of Set 26 | vanavara
# Processing Record 6 of Set 26 | laguna
# Processing Record 7 of Set 26 | emerald
# Processing Record 8 of Set 26 | maceio
# Processing Record 9 of Set 26 | binga
# Processing Record 10 of Set 26 | stabat
# Processing Record 11 of Set 26 | marzuq
# Processing Record 12 of Set 26 | bodden town
# Processing Record 13 of Set 26 | bouna
# Processing Record 14 of Set 26 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 26 | talara
# Processing Record 16 of Set 26 | brownwood
# Processing Record 17 of Set 26 | tura
# Processing Record 18 of Set 26 | neftcala
# Processing Record 19 of Set 26 | nikolayevsk-na-amure
# Processing Record 20 of Set 26 | kalaleh
# Processing Record 21 of Set 26 | uusikaupunki
# Processing Record 22 of Set 26 | gurupa
# Processing Record 23 of Set 26 | san andres
# Processing Record 24 of Set 26 | nabire
# Processing Record 25 of Set 26 | snyder
# Processing Record 26 of Set 26 | rondonopolis
# Processing Record 27 of Set 26 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 26 | de aar
# Processing Record 29 of Set 26 | umm lajj
# Processing Record 30 of Set 26 | camana
# Processing Record 31 of Set 26 | djibo
# Processing Record 32 of Set 26 | jiazi
# Processing Record 33 of Set 26 | pangkalanbuun
# Processing Record 34 of Set 26 | pachino
# Processing Record 35 of Set 26 | bocaranga
# City not found. Skipping...
# Processing Record 36 of Set 26 | pudozh
# Processing Record 37 of Set 26 | kirkwall
# Processing Record 38 of Set 26 | nioro
# Processing Record 39 of Set 26 | jalingo
# Processing Record 40 of Set 26 | awallan
# Processing Record 41 of Set 26 | vaitape
# Processing Record 42 of Set 26 | bilma
# Processing Record 43 of Set 26 | half moon bay
# Processing Record 44 of Set 26 | gornoye loo
# Processing Record 45 of Set 26 | pochutla
# Processing Record 46 of Set 26 | yangambi
# Processing Record 47 of Set 26 | biltine
# Processing Record 48 of Set 26 | williams lake
# Processing Record 49 of Set 26 | gizo
# Processing Record 50 of Set 26 | straumen
# Processing Record 1 of Set 27 | samfya
# Processing Record 2 of Set 27 | gigmoto
# Processing Record 3 of Set 27 | heihe
# Processing Record 4 of Set 27 | gallup
# Processing Record 5 of Set 27 | chardara
# Processing Record 6 of Set 27 | bud
# Processing Record 7 of Set 27 | gaogou
# Processing Record 8 of Set 27 | teguise
# Processing Record 9 of Set 27 | pallasovka
# Processing Record 10 of Set 27 | marienburg
# Processing Record 11 of Set 27 | burnie
# Processing Record 12 of Set 27 | pisco
# Processing Record 13 of Set 27 | polikhnitos
# City not found. Skipping...
# Processing Record 14 of Set 27 | tamana
# Processing Record 15 of Set 27 | seybaplaya
# Processing Record 16 of Set 27 | alice springs
# Processing Record 17 of Set 27 | awbari
# Processing Record 18 of Set 27 | berdigestyakh
# Processing Record 19 of Set 27 | vryheid
# Processing Record 20 of Set 27 | warwick
# Processing Record 21 of Set 27 | harper
# Processing Record 22 of Set 27 | benalla
# Processing Record 23 of Set 27 | atar
# Processing Record 24 of Set 27 | kamenka
# Processing Record 25 of Set 27 | brus
# Processing Record 26 of Set 27 | canon city
# Processing Record 27 of Set 27 | inhambane
# Processing Record 28 of Set 27 | el wasta
# City not found. Skipping...
# Processing Record 29 of Set 27 | zhanaozen
# Processing Record 30 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 27 | pozo colorado
# Processing Record 32 of Set 27 | fare
# Processing Record 33 of Set 27 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 27 | gien
# Processing Record 35 of Set 27 | iqaluit
# Processing Record 36 of Set 27 | bonthe
# Processing Record 37 of Set 27 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 27 | kungurtug
# Processing Record 39 of Set 27 | christchurch
# Processing Record 40 of Set 27 | pamekasan
# Processing Record 41 of Set 27 | nynashamn
# Processing Record 42 of Set 27 | ornskoldsvik
# Processing Record 43 of Set 27 | tevaitoa
# Processing Record 44 of Set 27 | pizhanka
# Processing Record 45 of Set 27 | fenoarivo atsinanana
# Processing Record 46 of Set 27 | egvekinot
# Processing Record 47 of Set 27 | sulangan
# Processing Record 48 of Set 27 | kemijarvi
# Processing Record 49 of Set 27 | vila franca do campo
# Processing Record 50 of Set 27 | marawi
# Processing Record 1 of Set 28 | raudeberg
# Processing Record 2 of Set 28 | sabalgarh
# Processing Record 3 of Set 28 | gat
# Processing Record 4 of Set 28 | esperance
# Processing Record 5 of Set 28 | cap malheureux
# Processing Record 6 of Set 28 | sayyan
# Processing Record 7 of Set 28 | henties bay
# Processing Record 8 of Set 28 | tvoroyri
# Processing Record 9 of Set 28 | port macquarie
# Processing Record 10 of Set 28 | kargil
# Processing Record 11 of Set 28 | san ignacio
# Processing Record 12 of Set 28 | cortez
# Processing Record 13 of Set 28 | areka
# Processing Record 14 of Set 28 | dunedin
# Processing Record 15 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 28 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 28 | tilichiki
# Processing Record 18 of Set 28 | terra santa
# Processing Record 19 of Set 28 | druzhba
# Processing Record 20 of Set 28 | kurayoshi
# Processing Record 21 of Set 28 | topolobampo
# Processing Record 22 of Set 28 | vidim
# Processing Record 23 of Set 28 | kruisfontein
# Processing Record 24 of Set 28 | port augusta
# Processing Record 25 of Set 28 | havelock
# Processing Record 26 of Set 28 | camalu
# Processing Record 27 of Set 28 | zheshart
# Processing Record 28 of Set 28 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 28 | northam
# Processing Record 30 of Set 28 | bogovarovo
# Processing Record 31 of Set 28 | punta gorda
# Processing Record 32 of Set 28 | ulaangom
# Processing Record 33 of Set 28 | wamba
# Processing Record 34 of Set 28 | toora-khem
# Processing Record 35 of Set 28 | coihaique
# Processing Record 36 of Set 28 | sancti spiritus
# Processing Record 37 of Set 28 | ulladulla
# Processing Record 38 of Set 28 | dawei
# Processing Record 39 of Set 28 | shawnee
# Processing Record 40 of Set 28 | arlit
# Processing Record 41 of Set 28 | herat
# Processing Record 42 of Set 28 | mendahara
# City not found. Skipping...
# Processing Record 43 of Set 28 | skjaerhollen
# City not found. Skipping...
# Processing Record 44 of Set 28 | chicama
# Processing Record 45 of Set 28 | teya
# Processing Record 46 of Set 28 | salinas
# Processing Record 47 of Set 28 | anloga
# Processing Record 48 of Set 28 | huntsville
# Processing Record 49 of Set 28 | grande-riviere
# City not found. Skipping...
# Processing Record 50 of Set 28 | antofagasta
# Processing Record 1 of Set 29 | luau
# Processing Record 2 of Set 29 | stiubieni
# Processing Record 3 of Set 29 | riyadh
# Processing Record 4 of Set 29 | oranjemund
# Processing Record 5 of Set 29 | sistranda
# Processing Record 6 of Set 29 | pula
# Processing Record 7 of Set 29 | makakilo city
# Processing Record 8 of Set 29 | marsa matruh
# Processing Record 9 of Set 29 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 29 | rocha
# Processing Record 11 of Set 29 | yumen
# Processing Record 12 of Set 29 | hambantota
# Processing Record 13 of Set 29 | vilhena
# Processing Record 14 of Set 29 | chandbali
# Processing Record 15 of Set 29 | meulaboh
# Processing Record 16 of Set 29 | duz
# City not found. Skipping...
# Processing Record 17 of Set 29 | carmelo
# Processing Record 18 of Set 29 | siocon
# Processing Record 19 of Set 29 | pringsewu
# Processing Record 20 of Set 29 | lasa
# Processing Record 21 of Set 29 | chabahar
# Processing Record 22 of Set 29 | beloha
# Processing Record 23 of Set 29 | johnstown
# Processing Record 24 of Set 29 | alamos
# Processing Record 25 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 29 | bismarck
# Processing Record 27 of Set 29 | salta
# Processing Record 28 of Set 29 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 29 | coolum beach
# Processing Record 30 of Set 29 | kashan
# Processing Record 31 of Set 29 | kharp
# Processing Record 32 of Set 29 | gorontalo
# Processing Record 33 of Set 29 | batsfjord
# Processing Record 34 of Set 29 | ambilobe
# Processing Record 35 of Set 29 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 29 | miramar
# Processing Record 37 of Set 29 | buala
# Processing Record 38 of Set 29 | boueni
# Processing Record 39 of Set 29 | buriti alegre
# Processing Record 40 of Set 29 | maltahohe
# Processing Record 41 of Set 29 | houston
# Processing Record 42 of Set 29 | beyneu
# Processing Record 43 of Set 29 | husavik
# Processing Record 44 of Set 29 | ongandjera
# Processing Record 45 of Set 29 | maniitsoq
# Processing Record 46 of Set 29 | whitehorse
# Processing Record 47 of Set 29 | oksbol
# Processing Record 48 of Set 29 | amarante do maranhao
# Processing Record 49 of Set 29 | iwaki
# Processing Record 50 of Set 29 | kindia
# Processing Record 1 of Set 30 | teberda
# Processing Record 2 of Set 30 | port hueneme
# Processing Record 3 of Set 30 | amli
# Processing Record 4 of Set 30 | carambei
# Processing Record 5 of Set 30 | alta floresta
# Processing Record 6 of Set 30 | alegrete
# Processing Record 7 of Set 30 | sijunjung
# Processing Record 8 of Set 30 | wasilla
# Processing Record 9 of Set 30 | belem de sao francisco
# Processing Record 10 of Set 30 | sobolevo
# Processing Record 11 of Set 30 | leogane
# Processing Record 12 of Set 30 | uk
# City not found. Skipping...
# Processing Record 13 of Set 30 | kuandian
# Processing Record 14 of Set 30 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 30 | kango
# Processing Record 16 of Set 30 | puerto santander
# Processing Record 17 of Set 30 | fort-shevchenko
# Processing Record 18 of Set 30 | pho chai
# Processing Record 19 of Set 30 | shubarkuduk
# Processing Record 20 of Set 30 | thunder bay
# Processing Record 21 of Set 30 | port hardy
# Processing Record 22 of Set 30 | asfi
# Processing Record 23 of Set 30 | muisne
# Processing Record 24 of Set 30 | maragogi
# Processing Record 25 of Set 30 | krutikha
# Processing Record 26 of Set 30 | waingapu
# Processing Record 27 of Set 30 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 30 | nantucket
# Processing Record 29 of Set 30 | palmer
# Processing Record 30 of Set 30 | kysyl-syr
# Processing Record 31 of Set 30 | rabo de peixe
# Processing Record 32 of Set 30 | moranbah
# Processing Record 33 of Set 30 | dudinka
# Processing Record 34 of Set 30 | saint stephen
# Processing Record 35 of Set 30 | kautokeino
# Processing Record 36 of Set 30 | erzin
# Processing Record 37 of Set 30 | arman
# Processing Record 38 of Set 30 | zlobin
# Processing Record 39 of Set 30 | den helder
# Processing Record 40 of Set 30 | seidu
# Processing Record 41 of Set 30 | kangaatsiaq
# Processing Record 42 of Set 30 | divnogorsk
# Processing Record 43 of Set 30 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 30 | ust-kut
# Processing Record 45 of Set 30 | price
# Processing Record 46 of Set 30 | lazaro cardenas
# Processing Record 47 of Set 30 | maridi
# Processing Record 48 of Set 30 | puerto narino
# Processing Record 49 of Set 30 | srandakan
# Processing Record 50 of Set 30 | fort frances
# Processing Record 1 of Set 31 | guarapari
# Processing Record 2 of Set 31 | shenzhen
# Processing Record 3 of Set 31 | dwarka
# Processing Record 4 of Set 31 | bluefield
# Processing Record 5 of Set 31 | amnat charoen
# Processing Record 6 of Set 31 | kirakira
# Processing Record 7 of Set 31 | banda aceh
# Processing Record 8 of Set 31 | makokou
# Processing Record 9 of Set 31 | saint-louis
# Processing Record 10 of Set 31 | abu samrah
# Processing Record 11 of Set 31 | bundaberg
# Processing Record 12 of Set 31 | umarkot
# Processing Record 13 of Set 31 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 31 | akdagmadeni
# Processing Record 15 of Set 31 | dinguiraye
# Processing Record 16 of Set 31 | srisailam
# Processing Record 17 of Set 31 | faaa
# Processing Record 18 of Set 31 | kovur
# Processing Record 19 of Set 31 | plyussa
# Processing Record 20 of Set 31 | iskateley
# Processing Record 21 of Set 31 | tamworth
# Processing Record 22 of Set 31 | kenai
# Processing Record 23 of Set 31 | mtambile
# Processing Record 24 of Set 31 | trelew
# Processing Record 25 of Set 31 | bow island
# Processing Record 26 of Set 31 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 31 | imeni zhelyabova
# Processing Record 28 of Set 31 | mogadishu
# Processing Record 29 of Set 31 | hue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     48.31        66         100
# 1  Vestmannaeyjar      IS  63.4427  -20.2734     42.87        88         100
# 2         Mataura      NZ -46.1927  168.8643     68.49        52          55
# 3        Antalaha      MG -14.9003   50.2788     76.53        88         100
# 4         Andenes      NO  69.3143   16.1194     15.78        92          12
# 5           Airai      TL  -8.9266  125.4092     71.11        75          48
# 6          Barrow      US  71.2906 -156.7887    -14.78        64           0
# 7    Encruzilhada      BR -15.5314  -40.9094     68.14        98         100
# 8       Hithadhoo      MV  -0.6000   73.0833     82.00        71          26
# 9           Kapaa      US  22.0752 -159.3190     77.32        70           0
#
#    Wind Speed Current Description
# 0       27.63     overcast clouds
# 1       21.14     overcast clouds
# 2        4.76       broken clouds
# 3        4.12     overcast clouds
# 4        6.91          few clouds
# 5        3.29    scattered clouds
# 6        0.00           clear sky
# 7        1.97     overcast clouds
# 8        6.11    scattered clouds
# 9        1.99           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Punta Arenas      CL -53.1500  -70.9167     48.31        66
# 1      Vestmannaeyjar      IS  63.4427  -20.2734     42.87        88
# 2             Mataura      NZ -46.1927  168.8643     68.49        52
# 3            Antalaha      MG -14.9003   50.2788     76.53        88
# 4             Andenes      NO  69.3143   16.1194     15.78        92
# ..                ...     ...      ...       ...       ...       ...
# 702            Trelew      AR -43.2490  -65.3051     67.98        49
# 703        Bow Island      CA  49.8668 -111.3684     15.06        78
# 704  Imeni Zhelyabova      RU  58.9544   36.5956      6.67        99
# 705         Mogadishu      SO   2.0371   45.3438     77.00        78
# 706               Hue      VN  16.4667  107.6000     80.71        65
#
#      Cloudiness  Wind Speed Current Description
# 0           100       27.63     overcast clouds
# 1           100       21.14     overcast clouds
# 2            55        4.76       broken clouds
# 3           100        4.12     overcast clouds
# 4            12        6.91          few clouds
# ..          ...         ...                 ...
# 702           7        6.49           clear sky
# 703          24        0.00          few clouds
# 704          90        2.39     overcast clouds
# 705          51       19.39       broken clouds
# 706          40        4.61    scattered clouds
#
# [707 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPY_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
